# %%
from cProfile import label
import ccxt
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import streamlit as st
from plotly.subplots import make_subplots
from PIL import Image
import math
import plotly.graph_objects as go
from datetime import datetime
import calendar

# Importar la biblioteca de Python que proporciona acceso a la API de Kraken
import krakenex

st.set_page_config(page_icon="📈", page_title="Crypto Dashboard")

# Inicializar una instancia de la clase que proporciona acceso a la API de Kraken
kraken = krakenex.API()

# Utilizar la instancia de la clase que proporciona acceso a la API de Kraken para hacer llamadas a la API
response = kraken.query_public('Ticker', {'pair': 'XXBTZUSD'})
print(response)

# Resto del código...
# Out:
# {'error': [], 'result': {'XXBTZUSD': {'a': ['16963.00000', '1', '1.000'], 'b': ['16962.90000', '1', '1.000'], 'c': ['16963.00000', '0.00244543'], 'v': ['331.81206294', '1083.89649366'], 'p': ['16993.07632', '17104.83677'], 't': [2451, 16830], 'l': ['16930.50000', '16930.50000'], 'h': ['17088.20000', '17269.90000'], 'o': '17088.20000'}}}

# %%
from cProfile import label
# import ccxt
import krakenex
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import streamlit as st
from plotly.subplots import make_subplots
from PIL import Image
import math
import plotly.graph_objects as go
from datetime import datetime
import calendar
import krakenex
from pykrakenapi import KrakenAPI

# %%
api = krakenex.API()
exchange = KrakenAPI(api)

# %%
symbol_list=['BTC/USD', 'ETH/USD', 'USDT/USD', 'AXS/USD', 'BNB/USD', 'XRP/USD', 'LTC/USD', 'MATIC/USD', 'SOL/USD', 'DOGE/USD']
timeframe_list=['1d','15s','1m', '5m', '15m', '1h',  '1w', '1M']
ema_list=[30,7,14,21,50,100,200]

# %%
variacion_diaria = exchange.get_ohlc_data('BTCUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('ETHUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('USDTUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('AXSUSD', interval=1440, ascending = True)
#variacion_diaria = exchange.get_ohlc_data('BNBUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('XRPUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('LTCUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('MATICUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('SOLUSD', interval=1440, ascending = True)
variacion_diaria = exchange.get_ohlc_data('DOGEUSD', interval=1440, ascending = True)

# %%
variacion_diaria = exchange.get_ohlc_data('DOGEUSD', interval=1440, ascending = True)

# %%
variacion_diaria[0]
# Out:
#                   time      open      high       low     close      vwap  \
# dtime
# 2020-12-23  1608681600  0.004530  0.004765  0.003700  0.003767  0.004247
# 2020-12-24  1608768000  0.003712  0.004589  0.003676  0.004569  0.004164
# 2020-12-25  1608854400  0.004638  0.004666  0.004397  0.004608  0.004509
# 2020-12-26  1608940800  0.004594  0.004638  0.004428  0.004500  0.004515
# 2020-12-27  1609027200  0.004503  0.004800  0.004400  0.004540  0.004628
# ...                ...       ...       ...       ...       ...       ...
# 2022-12-08  1670457600  0.095791  0.099114  0.094601  0.098586  0.096752
# 2022-12-09  1670544000  0.098581  0.099390  0.094998  0.096701  0.097353
# 2022-12-10  1670630400  0.096751  0.097457  0.096074  0.096283  0.096754
# 2022-12-11  1670716800  0.096340  0.097165  0.091536  0.092684  0.095298
# 2022-12-12  1670803200  0.092599  0.092962  0.091842  0.092631  0.092476
#
#                   volume  count
# dtime
# 2020-12-23  1.205273e+08    885
# ...

# %%
variacion_diaria[0].close.values[-1]
# Out:
# 0.0965506

# %%
df_market_var_diaria=variacion_diaria[0]

# %%
df_market_var_diaria['close'].values[-1], "{:.2%}".format(((((df_market_var_diaria['close'].values[-1])/(df_market_var_diaria['close'].values[-2]))-1)))
# Out:
# (0.0965506, '0.28%')

# %%
variacion_diaria=pd.DataFrame(variacion_diaria)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
variacion_diaria
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Celda 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X20sdW50aXRsZWQ%3D?line=0'>1</a> variacion_diaria.type
#
# AttributeError: 'tuple' object has no attribute 'type'

# %%
df_market_var_diaria=pd.DataFrame(variacion_diaria, columns=['time','open', 'high', 'low', 'close','vwap','volume','count'])
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Celda 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X12sdW50aXRsZWQ%3D?line=0'>1</a> df_market_var_diaria=pd.DataFrame(variacion_diaria, columns=['time','open', 'high', 'low', 'close','vwap','volume','count'])
#
# ...

# %%
df_market_var_diaria=(variacion_diaria, columns=['time','open', 'high', 'low', 'close','vwap','volume','count'])
# Out:
#   Input In [37]
#     df_market_var_diaria=(variacion_diaria, columns=['time','open', 'high', 'low', 'close','vwap','volume','count'])
#                                             ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import pykrakenapi

# %%
ohlc = k.get_ohlc_data('BTCUSD', interval=1440, ascending = True)
ohlc[0].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Celda 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=0'>1</a> ohlc = k.get_ohlc_data('BTCUSD', interval=1440, ascending = True)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=1'>2</a> ohlc[0].head()
#
# NameError: name 'k' is not defined

# %%
ohlc = k.get_ohlc_data(pair="btcUSD",interval=60)
print(ohlc)
# Out:
# (                           time     open     high      low    close     vwap  \
# dtime
# 2022-12-11 00:00:00  1670716800  17125.0  17132.7  17122.0  17129.6  17126.0
# 2022-12-10 23:00:00  1670713200  17130.5  17144.9  17096.1  17124.0  17122.2
# 2022-12-10 22:00:00  1670709600  17125.9  17152.9  17116.2  17130.5  17135.3
# 2022-12-10 21:00:00  1670706000  17172.6  17175.5  17123.4  17126.2  17142.3
# 2022-12-10 20:00:00  1670702400  17177.1  17179.9  17165.6  17171.3  17173.6
# ...                         ...      ...      ...      ...      ...      ...
# 2022-11-11 05:00:00  1668142800  17010.2  17332.9  16999.3  17303.5  17153.6
# 2022-11-11 04:00:00  1668139200  16999.9  17106.6  16934.3  17010.2  17021.1
# 2022-11-11 03:00:00  1668135600  17153.7  17161.2  16833.8  17000.3  16965.0
# 2022-11-11 02:00:00  1668132000  17212.8  17286.7  16970.8  17154.0  17105.5
# 2022-11-11 01:00:00  1668128400  17506.6  17638.0  17156.0  17212.6  17371.8
#
# ...

# %%
pairs = k.get_tradable_asset_pairs()
# Out:
#            altname     wsname aclass_base   base aclass_quote quote   lot  \
# 1INCHEUR  1INCHEUR  1INCH/EUR    currency  1INCH     currency  ZEUR  unit
# 1INCHUSD  1INCHUSD  1INCH/USD    currency  1INCH     currency  ZUSD  unit
# AAVEAUD    AAVEAUD   AAVE/AUD    currency   AAVE     currency  ZAUD  unit
# AAVEETH    AAVEETH   AAVE/ETH    currency   AAVE     currency  XETH  unit
# AAVEEUR    AAVEEUR   AAVE/EUR    currency   AAVE     currency  ZEUR  unit
# ...            ...        ...         ...    ...          ...   ...   ...
# ZRXGBP      ZRXGBP    ZRX/GBP    currency    ZRX     currency  ZGBP  unit
# ZRXUSD      ZRXUSD    ZRX/USD    currency    ZRX     currency  ZUSD  unit
# ZRXXBT      ZRXXBT    ZRX/XBT    currency    ZRX     currency  XXBT  unit
# ZUSDZCAD    USDCAD    USD/CAD    currency   ZUSD     currency  ZCAD  unit
# ZUSDZJPY    USDJPY    USD/JPY    currency   ZUSD     currency  ZJPY  unit
#
#          cost_decimals pair_decimals lot_decimals  ...  \
# ...

# %%
pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 660 entries, 1INCHEUR to ZUSDZJPY
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   altname               660 non-null    object
#  1   wsname                660 non-null    object
#  2   aclass_base           660 non-null    object
#  3   base                  660 non-null    object
#  4   aclass_quote          660 non-null    object
#  5   quote                 660 non-null    object
#  6   lot                   660 non-null    object
#  7   cost_decimals         660 non-null    object
#  8   pair_decimals         660 non-null    object
#  9   lot_decimals          660 non-null    object
#  10  lot_multiplier        660 non-null    object
#  11  leverage_buy          660 non-null    object
#  12  leverage_sell         660 non-null    object
#  13  fees                  660 non-null    object
#  14  fees_maker            660 non-null    object
# ...

# %%
pairs.altname.unique()
# Out:
# array(['1INCHEUR', '1INCHUSD', 'AAVEAUD', 'AAVEETH', 'AAVEEUR', 'AAVEGBP',
#        'AAVEUSD', 'AAVEXBT', 'ACAEUR', 'ACAUSD', 'ACHEUR', 'ACHUSD',
#        'ADAAUD', 'ADAETH', 'ADAEUR', 'ADAGBP', 'ADAUSD', 'ADAUSDT',
#        'ADAXBT', 'ADXEUR', 'ADXUSD', 'AGLDEUR', 'AGLDUSD', 'AIREUR',
#        'AIRUSD', 'AKTEUR', 'AKTUSD', 'ALCXEUR', 'ALCXUSD', 'ALGOETH',
#        'ALGOEUR', 'ALGOGBP', 'ALGOUSD', 'ALGOUSDT', 'ALGOXBT', 'ALICEEUR',
#        'ALICEUSD', 'ALPHAEUR', 'ALPHAUSD', 'ANKREUR', 'ANKRGBP',
#        'ANKRUSD', 'ANKRXBT', 'ANTETH', 'ANTEUR', 'ANTUSD', 'ANTXBT',
#        'APEEUR', 'APEUSD', 'APEUSDT', 'API3EUR', 'API3USD', 'APTEUR',
#        'APTUSD', 'ARPAEUR', 'ARPAUSD', 'ASTREUR', 'ASTRUSD', 'ATLASEUR',
#        'ATLASUSD', 'ATOMAUD', 'ATOMETH', 'ATOMEUR', 'ATOMGBP', 'ATOMUSD',
#        'ATOMUSDT', 'ATOMXBT', 'AUDIOEUR', 'AUDIOUSD', 'AUDJPY', 'AUDUSD',
#        'AVAXEUR', 'AVAXUSD', 'AVAXUSDT', 'AXSEUR', 'AXSUSD', 'BADGEREUR',
# ...

# %%
pairs[pairs.altname.str.contains('BN')]
# Out:
#        altname   wsname aclass_base base aclass_quote quote   lot  \
# BNCEUR  BNCEUR  BNC/EUR    currency  BNC     currency  ZEUR  unit
# BNCUSD  BNCUSD  BNC/USD    currency  BNC     currency  ZUSD  unit
# BNTEUR  BNTEUR  BNT/EUR    currency  BNT     currency  ZEUR  unit
# BNTGBP  BNTGBP  BNT/GBP    currency  BNT     currency  ZGBP  unit
# BNTUSD  BNTUSD  BNT/USD    currency  BNT     currency  ZUSD  unit
# BNTXBT  BNTXBT  BNT/XBT    currency  BNT     currency  XXBT  unit
#
#        cost_decimals pair_decimals lot_decimals  ...  \
# BNCEUR             5             3            8  ...
# BNCUSD             5             3            8  ...
# BNTEUR             5             3            8  ...
# BNTGBP             5             3            8  ...
# BNTUSD             5             3            8  ...
# BNTXBT             9             7            8  ...
#
#                                                fees_maker fee_volume_currency  \
# ...

# %%
            eleccion = 'BTCUSD'
            
            
            grafo1 = exchange.get_ohlc_data(eleccion, interval=1440, ascending = True)
            grafo2 = grafo1[0]
            #df_market=pd.DataFrame(ohlcv, columns=['timestamp','open', 'high', 'low', 'close','volume'])
            #df_market['timestamp']=pd.to_datetime(df_market['timestamp'],unit='ms')
            #df_market['SMA'] = df_market.close.rolling(ematime).mean()
            #df_market['VAR'] = df_market.close.rolling(vartime).var()
            #df_market['DESV'] = df_market.close.rolling(vartime).std()

            portada=eleccion.replace('/USD','')

            import plotly.graph_objects as go
            import plotly.express as px

            fig = go.Figure(data=[go.Candlestick(x = grafo2.index,
                                                open = grafo2['open'],
                                                high = grafo2['high'],
                                                low = grafo2['low'],
                                                close = grafo2['close'],
                                                ),
                                go.Scatter(x=grafo2.index, y=grafo2['20 SMA'], line=dict(color='purple', width=1))])

            fig.show()
# Out:
# attempt: 000 | ['EGeneral:Too many requests']
# attempt: 001 | ['EGeneral:Too many requests']
# attempt: 002 | ['EGeneral:Too many requests']
# attempt: 003 | ['EGeneral:Too many requests']
# attempt: 004 | ['EGeneral:Too many requests']
# attempt: 005 | ['EGeneral:Too many requests']
# attempt: 006 | ['EGeneral:Too many requests']
# attempt: 007 | ['EGeneral:Too many requests']
# attempt: 008 | ['EGeneral:Too many requests']
# attempt: 009 | ['EGeneral:Too many requests']
# attempt: 010 | ['EGeneral:Too many requests']
# attempt: 011 | ['EGeneral:Too many requests']
# attempt: 012 | ['EGeneral:Too many requests']
# attempt: 013 | ['EGeneral:Too many requests']
# attempt: 014 | ['EGeneral:Too many requests']
# attempt: 015 | ['EGeneral:Too many requests']
# attempt: 016 | ['EGeneral:Too many requests']
# attempt: 017 | ['EGeneral:Too many requests']
# ---------------------------------------------------------------------------
# ...

# %%
ohlc = exchange.get_ohlc_data('BTCUSD', interval=1440, ascending = True)
ohlc[0].head()
# Out:
# attempt: 000 | ['EGeneral:Too many requests']
# attempt: 001 | ['EGeneral:Too many requests']
#                   time     open     high      low    close     vwap  \
# dtime
# 2020-12-23  1608681600  23823.0  24080.0  22629.2  23226.7  23452.8
# 2020-12-24  1608768000  23225.5  23750.0  22723.0  23718.6  23231.1
# 2020-12-25  1608854400  23718.7  24777.7  23410.8  24698.6  24176.9
# 2020-12-26  1608940800  24703.8  26800.0  24500.0  26441.2  25689.5
# 2020-12-27  1609027200  26442.2  28353.2  25634.6  26251.4  27070.5
#
#                   volume  count
# dtime
# 2020-12-23   8830.551956  44382
# 2020-12-24   4800.525211  26793
# 2020-12-25   6178.779515  32557
# 2020-12-26   9648.055367  50215
# 2020-12-27  14257.998617  82308

# %%
import pandas as pd

ohlc[0]['20 SMA'] = ohlc[0]['close'].rolling(20).mean()
ohlc[0].tail()
# Out:
#                   time     open     high      low    close     vwap  \
# dtime
# 2022-12-08  1670457600  16836.9  17298.9  16735.9  17228.5  17036.7
# 2022-12-09  1670544000  17228.0  17366.2  17066.6  17131.1  17181.9
# 2022-12-10  1670630400  17131.3  17226.8  17096.1  17124.0  17162.6
# 2022-12-11  1670716800  17125.0  17269.9  17070.4  17085.8  17153.3
# 2022-12-12  1670803200  17088.2  17088.2  16930.5  16963.0  16993.0
#
#                  volume  count     20 SMA
# dtime
# 2022-12-08  2506.397872  20308  16673.685
# 2022-12-09  2164.101257  20646  16696.125
# 2022-12-10   605.400887  14289  16739.095
# 2022-12-11   787.647864  15532  16805.385
# 2022-12-12   331.846016   2454  16843.785

# %%
            eleccion = 'BTCUSD'
            ohlc = exchange.get_ohlc_data(eleccion, interval=1440, ascending = True)
            ohlc[0]['20 SMA'] = ohlc[0]['close'].rolling(20).mean()

            portada=eleccion.replace('/USD','')

            import plotly.graph_objects as go
            import plotly.express as px

            fig = go.Figure(data=[go.Candlestick(x = ohlc[0].index,
                                                open = ohlc[0]['open'],
                                                high = ohlc[0]['high'],
                                                low = ohlc[0]['low'],
                                                close = ohlc[0]['close'],
                                                ),
                                go.Scatter(x=ohlc[0].index, y=ohlc[0]['20 SMA'], line=dict(color='purple', width=1))])

            fig.show()
# Out:
# attempt: 000 | ['EGeneral:Too many requests']
