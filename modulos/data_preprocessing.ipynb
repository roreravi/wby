# %%
import pandas as pd
import glob
import warnings
import urllib.request
import ssl

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# https://raw.githubusercontent.com/toledojm/wby/main/data/data_jan-feb_22.csv

# %%
url="https://raw.githubusercontent.com/toledojm/wby/main/data/data_jan-feb_22.csv"

# %%
ssl._create_default_https_context = ssl._create_unverified_context
ruta = urllib.request.urlopen(url)

# %%
df1_2 = pd.read_csv(ruta, delimiter = ';' ,on_bad_lines='skip')

# %%
df1_2
# Out:
#       IDOficina    Oficina      Iata  IDTipoDoc TipoDoc  FolioDoc FechaEmiDoc  \
# 0            10        TMC  86516220         28     DST     45402  03/01/2022
# 1            10        TMC  86516220         28     DST     45403  03/01/2022
# 2            10        TMC  86516220         28     DST     45404  03/01/2022
# 3            10        TMC  86516220         28     DST     45408  03/01/2022
# 4            10        TMC  86516220         28     DST     45409  03/01/2022
# ...         ...        ...       ...        ...     ...       ...         ...
# 4857          3  ASOCIADOS  86516220         26   NCFAA       204  14/02/2022
# 4858          3  ASOCIADOS  86516220         26   NCFAA       204  14/02/2022
# 4859          3  ASOCIADOS  86516220         26   NCFAA       204  14/02/2022
# 4860         10        TMC  86516220         30   NCDST       365  27/01/2022
# 4861         10        TMC  86516220         30   NCDST       366  27/01/2022
#
#      FechaBoleto  IDMoneda MonedaDoc  ...     Costo  ClaveAerolinea  \
# 0     03/01/2022         1       MXN  ...   2077.36          1/2022
# 1            NaN         2       USD  ...  43701.28             NaN
# 2     03/01/2022         1       MXN  ...   1049.00          ODJ48Q
# 3     03/01/2022         1       MXN  ...   2209.68          DSNGGA
# 4     03/01/2022         1       MXN  ...   3243.24          SQPXWR
# ...          ...       ...       ...  ...       ...             ...
# 4857  31/12/1899         1       MXN  ...      0.00             NaN
# 4858  31/12/1899         1       MXN  ...      0.00             NaN
# 4859  31/12/1899         1       MXN  ...      0.00             NaN
# 4860  31/12/1899         1       MXN  ...      0.00          FE9EYA
# 4861  31/12/1899         1       MXN  ...      0.00          FE9EYA
#
#      FacturaComision Transacciones BookingType               Usuario  \
# 0                  0             1         NaN  ADMINISTRADOR ADMIN1
# 1                  0             1         NaN        PATRICIA TREJO
# 2                  0             1         NaN  ADMINISTRADOR ADMIN1
# 3                  0             1         NaN  ADMINISTRADOR ADMIN1
# 4                  0             1         NaN  ADMINISTRADOR ADMIN1
# ...              ...           ...         ...                   ...
# 4857               0             1         OFF        PATRICIA TREJO
# 4858               0             1         OFF        PATRICIA TREJO
# 4859               0             1         OFF        PATRICIA TREJO
# 4860               0             1         OFF        PATRICIA TREJO
# 4861               0             1         OFF        PATRICIA TREJO
#
#         ProveedorRFC Observa SolicitudPago CuponHotel
# 0     AAI-580414-GA9     NaN             0          0
# 1           -      -                     0          0
# 2     CVA-041027-H80     NaN             0          0
# 3     AME-880912-I89     NaN             0          0
# 4     AME-880912-I89     NaN             0          0
# ...              ...     ...           ...        ...
# 4857  TTV-081210-7N4     NaN             0          0
# 4858  TTV-081210-7N4     NaN             0          0
# 4859        -      -     NaN             0          0
# 4860  CVA-041027-H80     NaN             0          0
# 4861  CVA-041027-H80     NaN             0          0
#
# [4862 rows x 175 columns]

# %%
# Podemos leer manualmente todos los archivos de la carpeta data
df1_2 = pd.read_csv("https://raw.githubusercontent.com/toledojm/wby/main/data/data_jan-feb_22.csv", delimiter = ';' ,on_bad_lines='skip')
df3_4 = pd.read_csv("data/data_mar-abr_22.csv", delimiter = ';' ,on_bad_lines='skip')
df5_6 = pd.read_csv("data/data_may_-_jun_22.csv", delimiter = ';' ,on_bad_lines='skip')
df9_10_11 = pd.read_csv("data/data_sep_--_nov_22.csv", delimiter = ';' ,on_bad_lines='skip')

# %%
# O podemos leerlos de manera automatica con la librería glob que lee los nombres de todos los archivos 
# contenidos en la carpeta data según la extensión que le especifiquemos
filenames = glob.glob('data' + "/*.csv")
dataframes = []
for file in filenames:
    dataframes.append(pd.read_csv(file,delimiter = ';' ,on_bad_lines='skip'))
# dataframes es una lista de dataframes que contienen los datos de todos los archivos
# aqui creamos un dataframe unico con todos los datos
df_actual = pd.concat(dataframes)

# %%
# Si creamos los dataframe de manera manual tenemos esta opción para contatenar
# Unimos los archivos
# Creamos una lista para almacenar los dataframe
df_list = []
# Almacenamos todos los Dataframe que se encuentran en el espacio de trabajo que comienzan por df
df_list.extend(value for name, value in locals().items() if name.startswith('df'))
# Se puede hacer de manera manual: df_list = [df1_2, df3_4, df5_6, df9_10_11]
# Se unen todos los dataframe
df_actual = pd.concat(df_list)

# %%
# Pasamos la columna fecha a datetime
df_actual['FechaEmiDoc']= pd.to_datetime(df_actual['FechaEmiDoc'])

# %%
# Ahora creamos los archivos por mes
months = df_actual['FechaEmiDoc'].dt.month.unique()
for i in months:
    mask = df_actual['FechaEmiDoc'].dt.month == i
    df = df_actual[mask]
    df.to_csv(f'monthly_data/data_month_{i}.csv', sep=';')
